# %%
import pandas as pd

# %%
datadf = pd.read_csv("Master2.csv")
datadf.info()
# Out:
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_85488/3120251749.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   datadf = pd.read_csv("Master2.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528644 entries, 0 to 528643
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      528644 non-null  int64
#  1   State           528644 non-null  object
#  2   County          528644 non-null  object
#  3   Year            528644 non-null  int64
#  4   Population      526949 non-null  float64
#  5   LandArea        526949 non-null  float64
#  6   Type            413703 non-null  object
#  7   CountByType     128859 non-null  float64
#  8   TotalCount      291792 non-null  float64
#  9   NonUSBorn       528490 non-null  float64
#  10  EducationType   528490 non-null  object
# ...

# %%
datadf.head(25)
# Out:
#     Unnamed: 0    State   County  Year  Population  LandArea    Type  \
# 0            1  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 1            2  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 2            3  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 3            4  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 4            5  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 5            6  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 6            7  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 7            8  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 8            9  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 9           10  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 10          11  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 11          12  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 12          13  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# ...

# %%
datadf["Type"].value_counts()

# %%
datadf["County"].value_counts()

# %%
datadf["EducationType"].value_counts()

# %%
datadf["State"].value_counts()

# %%
cleaneddf = datadf

# %%
columns = ['Unnamed: 0','CountByType', 'TotalCount', 'CommuteCount']
datadf.drop(columns, inplace=True, axis=1)

# %%
datadf
# Out:
#              State    County  Year  Population  LandArea    Type  NonUSBorn  \
# 0          Alabama   Baldwin  2011    186717.0   1589.78  Heroin     5147.0
# 1          Alabama   Baldwin  2011    186717.0   1589.78  Heroin     5147.0
# 2          Alabama   Baldwin  2011    186717.0   1589.78  Heroin     5147.0
# 3          Alabama   Baldwin  2011    186717.0   1589.78  Heroin     5147.0
# 4          Alabama   Baldwin  2011    186717.0   1589.78  Heroin     5147.0
# ...            ...       ...   ...         ...       ...     ...        ...
# 528639  New Mexico  Do?a Ana  2017         NaN       NaN     NaN        NaN
# 528640  New Mexico  Do?a Ana  2017         NaN       NaN     NaN        NaN
# 528641  New Mexico  Do?a Ana  2017         NaN       NaN     NaN        NaN
# 528642  New Mexico  Do?a Ana  2017         NaN       NaN     NaN        NaN
# 528643  New Mexico  Do?a Ana  2017         NaN       NaN     NaN        NaN
#
# ...

# %%
statesdf = datadf.sort_values(["State"], ascending=True)
statesdf
# Out:
#           State   County  Year  Population  LandArea         Type  NonUSBorn  \
# 0       Alabama  Baldwin  2011    186717.0   1589.78       Heroin     5147.0
# 19653   Alabama  Baldwin  2012    190790.0   1589.78       Heroin     5149.0
# 157727  Alabama   Mobile  2012    413936.0   1229.44  Other Opiod    10578.0
# 157728  Alabama   Mobile  2012    413936.0   1229.44  Other Opiod    10578.0
# 157729  Alabama   Mobile  2012    413936.0   1229.44  Other Opiod    10578.0
# ...         ...      ...   ...         ...       ...          ...        ...
# 413678  Wyoming  Natrona  2017     79547.0   5340.35    Methadone     1981.0
# 413677  Wyoming  Natrona  2017     79547.0   5340.35    Methadone     1981.0
# 413676  Wyoming  Natrona  2017     79547.0   5340.35    Methadone     1981.0
# 374158  Wyoming  Fremont  2015     40315.0   9183.81    Methadone      491.0
# 216586  Wyoming  Natrona  2014     81624.0   5340.35  Other Opiod     1604.0
#
# ...

# %%
yearsdf = datadf.sort_values(["Year"], ascending=True)
yearsdf
# Out:
#               State    County  Year  Population  LandArea         Type  \
# 0           Alabama   Baldwin  2011    186717.0   1589.78       Heroin
# 140142  Connecticut   Tolland  2011    152507.0    410.21  Other Opiod
# 140141  Connecticut   Tolland  2011    152507.0    410.21  Other Opiod
# 140140  Connecticut   Tolland  2011    152507.0    410.21  Other Opiod
# 140139  Connecticut   Tolland  2011    152507.0    410.21  Other Opiod
# ...             ...       ...   ...         ...       ...          ...
# 275796      Wyoming   Natrona  2017     79547.0   5340.35  Other Opiod
# 275795      Wyoming   Natrona  2017     79547.0   5340.35  Other Opiod
# 275794      Wyoming   Natrona  2017     79547.0   5340.35  Other Opiod
# 275792      Wyoming   Natrona  2017     79547.0   5340.35  Other Opiod
# 528643   New Mexico  Do?a Ana  2017         NaN       NaN          NaN
#
#         NonUSBorn    EducationType  EducationCount     CommuteType   Income
# ...

# %%
populationdf = datadf.sort_values(["Population"], ascending=True)
populationdf

# %%
drugtypedf = datadf.sort_values(["Type"], ascending=True)
drugtypedf

# %%
educationdf = datadf.sort_values(["EducationType"], ascending=True)
educationdf

# %%
commutedf = datadf.sort_values(["CommuteType"], ascending=True)
commutedf

# %%
incomedf = datadf.sort_values(["Income"], ascending=True)
incomedf
