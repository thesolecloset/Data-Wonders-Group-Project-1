# %%
import pandas as pd

# %%
datadf = pd.read_csv("Master2.csv")
datadf.info()
# Out:
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_2994/3120251749.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   datadf = pd.read_csv("Master2.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528644 entries, 0 to 528643
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      528644 non-null  int64
#  1   State           528644 non-null  object
#  2   County          528644 non-null  object
#  3   Year            528644 non-null  int64
#  4   Population      526949 non-null  float64
#  5   LandArea        526949 non-null  float64
#  6   Type            413703 non-null  object
#  7   CountByType     128859 non-null  float64
#  8   TotalCount      291792 non-null  float64
#  9   NonUSBorn       528490 non-null  float64
#  10  EducationType   528490 non-null  object
#  11  EducationCount  528490 non-null  float64
# ...

# %%
datadf.head(25)
# Out:
#     Unnamed: 0    State   County  Year  Population  LandArea    Type  \
# 0            1  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 1            2  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 2            3  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 3            4  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 4            5  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 5            6  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 6            7  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 7            8  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 8            9  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 9           10  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 10          11  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 11          12  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# 12          13  Alabama  Baldwin  2011    186717.0   1589.78  Heroin
# ...

# %%
datadf["Type"].value_counts()
# Out:
# Heroin         137901
# Other Opiod    137901
# Methadone      137901
# Name: Type, dtype: int64

# %%
datadf["County"].value_counts()
# Out:
# Washington         6125
# Jefferson          5880
# Madison            4060
# Montgomery         3955
# Monroe             3570
#                    ...
# Prince of Wales       7
# Do¸æç£§ºa Ana         7
# Yukon                 7
# Matanuska             7
# La Salle Parish       5
# Name: County, Length: 1890, dtype: int64

# %%
datadf["EducationType"].value_counts()
# Out:
# Less Than HS                      105698
# HS Grad                           105698
# Some College/Associates Degree    105698
# Bachelor Degree                   105698
# Grad Degree                       105698
# Name: EducationType, dtype: int64

# %%
datadf["State"].value_counts()
# Out:
# Texas             28270
# North Carolina    27300
# Florida           25362
# Ohio              25075
# Pennsylvania      24255
# California        23100
# New York          23065
# Georgia           22155
# Virginia          19230
# Michigan          18200
# Illinois          16555
# Indiana           15930
# Tennessee         15645
# Wisconsin         14665
# New Jersey        12390
# Kentucky          12355
# South Carolina    12100
# Washington        11970
# Missouri          11270
# Maryland          10590
# Alabama           10220
# Oklahoma           9310
# Minnesota          9200
# Colorado           8860
# Louisiana          8645
# Oregon             8155
# Iowa               7735
# Massachusetts      7630
# Kansas             7595
# West Virginia      7420
# Mississippi        6790
# Arkansas           6720
# New Mexico         5950
# Connecticut        5040
# Utah               4940
# Arizona            4795
# Nebraska           4620
# Idaho              4270
# ...

# %%
cleaneddf = datadf

# %%
columns = ['Unnamed: 0','CountByType', 'CommuteCount']
datadf.drop(columns, inplace=True, axis=1)

# %%
cleaneddf = datadf.dropna()

# %%
cleaneddf
# Out:
#             State     County  Year  Population  LandArea       Type  \
# 0         Alabama    Baldwin  2011    186717.0   1589.78     Heroin
# 1         Alabama    Baldwin  2011    186717.0   1589.78     Heroin
# 2         Alabama    Baldwin  2011    186717.0   1589.78     Heroin
# 3         Alabama    Baldwin  2011    186717.0   1589.78     Heroin
# 4         Alabama    Baldwin  2011    186717.0   1589.78     Heroin
# ...           ...        ...   ...         ...       ...        ...
# 413663  Wisconsin  Winnebago  2017    170414.0    434.49  Methadone
# 413664  Wisconsin  Winnebago  2017    170414.0    434.49  Methadone
# 413665  Wisconsin  Winnebago  2017    170414.0    434.49  Methadone
# 413666  Wisconsin  Winnebago  2017    170414.0    434.49  Methadone
# 413667  Wisconsin  Winnebago  2017    170414.0    434.49  Methadone
#
#         TotalCount  NonUSBorn EducationType  EducationCount     CommuteType  \
# ...

# %%
statesdf = cleaneddf.sort_values(["State"], ascending=True)
statesdf
# Out:
#           State   County  Year  Population  LandArea       Type  TotalCount  \
# 0       Alabama  Baldwin  2011    186717.0   1589.78     Heroin        10.0
# 295657  Alabama   Shelby  2012    200941.0    784.93  Methadone        14.0
# 295656  Alabama   Shelby  2012    200941.0    784.93  Methadone        14.0
# 295655  Alabama   Shelby  2012    200941.0    784.93  Methadone        14.0
# 295654  Alabama   Shelby  2012    200941.0    784.93  Methadone        14.0
# ...         ...      ...   ...         ...       ...        ...         ...
# 354466  Wyoming  Natrona  2014     81624.0   5340.35  Methadone        10.0
# 78664   Wyoming  Natrona  2014     81624.0   5340.35     Heroin        10.0
# 78663   Wyoming  Natrona  2014     81624.0   5340.35     Heroin        10.0
# 78673   Wyoming  Natrona  2014     81624.0   5340.35     Heroin        10.0
# 78665   Wyoming  Natrona  2014     81624.0   5340.35     Heroin        10.0
#
# ...

# %%
populationdf = cleaneddf.sort_values(["Population"], ascending=True)
populationdf
# Out:
#              State       County  Year  Population  LandArea         Type  \
# 85109     Kentucky         Pike  2015     61792.0    786.83       Heroin
# 360915    Kentucky         Pike  2015     61792.0    786.83    Methadone
# 360914    Kentucky         Pike  2015     61792.0    786.83    Methadone
# 360913    Kentucky         Pike  2015     61792.0    786.83    Methadone
# 360912    Kentucky         Pike  2015     61792.0    786.83    Methadone
# ...            ...          ...   ...         ...       ...          ...
# 217516  California  Los Angeles  2015  10170292.0   4057.88  Other Opiod
# 217515  California  Los Angeles  2015  10170292.0   4057.88  Other Opiod
# 217514  California  Los Angeles  2015  10170292.0   4057.88  Other Opiod
# 217512  California  Los Angeles  2015  10170292.0   4057.88  Other Opiod
# 217506  California  Los Angeles  2015  10170292.0   4057.88  Other Opiod
#
#         TotalCount  NonUSBorn EducationType  EducationCount     CommuteType  \
# ...

# %%
yearsdf = cleaneddf.sort_values(["Year"], ascending=True)
yearsdf
# Out:
#             State     County  Year  Population  LandArea         Type  \
# 0         Alabama    Baldwin  2011    186717.0   1589.78       Heroin
# 143991   Kentucky   Campbell  2011     90940.0    151.31  Other Opiod
# 143990   Kentucky   Campbell  2011     90940.0    151.31  Other Opiod
# 143989   Kentucky   Campbell  2011     90940.0    151.31  Other Opiod
# 143988   Kentucky   Campbell  2011     90940.0    151.31  Other Opiod
# ...           ...        ...   ...         ...       ...          ...
# 261119   Illinois  Winnebago  2017    284778.0    513.36  Other Opiod
# 261118   Illinois  Winnebago  2017    284778.0    513.36  Other Opiod
# 261117   Illinois  Winnebago  2017    284778.0    513.36  Other Opiod
# 261115   Illinois  Winnebago  2017    284778.0    513.36  Other Opiod
# 413667  Wisconsin  Winnebago  2017    170414.0    434.49    Methadone
#
#         TotalCount  NonUSBorn EducationType  EducationCount     CommuteType  \
# ...

# %%
drugtypedf = cleaneddf.sort_values(["Type"], ascending=True)
drugtypedf
# Out:
#              State   County  Year  Population  LandArea         Type  \
# 0          Alabama  Baldwin  2011    186717.0   1589.78       Heroin
# 97055   Washington    Clark  2015    459495.0    629.00       Heroin
# 97054   Washington    Clark  2015    459495.0    629.00       Heroin
# 97053   Washington    Clark  2015    459495.0    629.00       Heroin
# 97052   Washington    Clark  2015    459495.0    629.00       Heroin
# ...            ...      ...   ...         ...       ...          ...
# 234954  Washington    Clark  2015    459495.0    629.00  Other Opiod
# 234955  Washington    Clark  2015    459495.0    629.00  Other Opiod
# 234956  Washington    Clark  2015    459495.0    629.00  Other Opiod
# 234947  Washington    Clark  2015    459495.0    629.00  Other Opiod
# 213067   Tennessee   Greene  2014     68335.0    622.16  Other Opiod
#
#         TotalCount  NonUSBorn                   EducationType  EducationCount  \
# ...

# %%
educationdf = cleaneddf.sort_values(["EducationType"], ascending=True)
educationdf
# Out:
#            State    County  Year  Population  LandArea         Type  \
# 137919   Alabama   Baldwin  2011    186717.0   1589.78  Other Opiod
# 194754      Utah     Weber  2013    238519.0    576.08  Other Opiod
# 194755      Utah     Weber  2013    238519.0    576.08  Other Opiod
# 194756      Utah     Weber  2013    238519.0    576.08  Other Opiod
# 194757      Utah     Weber  2013    238519.0    576.08  Other Opiod
# ...          ...       ...   ...         ...       ...          ...
# 106394  Michigan  Isabella  2016     71282.0    572.68       Heroin
# 106395  Michigan  Isabella  2016     71282.0    572.68       Heroin
# 106396  Michigan  Isabella  2016     71282.0    572.68       Heroin
# 359085  Illinois      Kane  2015    530847.0    520.06    Methadone
# 70293   New York    Ulster  2014    180445.0   1124.24       Heroin
#
#         TotalCount  NonUSBorn                   EducationType  EducationCount  \
# ...

# %%
commutedf = cleaneddf.sort_values(["CommuteType"], ascending=True)
commutedf
# Out:
#                 State     County  Year  Population  LandArea         Type  \
# 0             Alabama    Baldwin  2011    186717.0   1589.78       Heroin
# 66744   Massachusetts  Worcester  2014    813475.0   1510.77       Heroin
# 294523     Washington     Yakima  2011    247141.0   4295.40    Methadone
# 226619     New Jersey     Sussex  2015    143673.0    519.01  Other Opiod
# 128580       New York     Broome  2017    193639.0    705.77       Heroin
# ...               ...        ...   ...         ...       ...          ...
# 240694          Idaho   Kootenai  2016    154311.0   1244.12  Other Opiod
# 240688          Idaho   Kootenai  2016    154311.0   1244.12  Other Opiod
# 240682          Idaho    Bannock  2016     84377.0   1111.99  Other Opiod
# 240759       Illinois  Champaign  2016    208419.0    996.27  Other Opiod
# 413667      Wisconsin  Winnebago  2017    170414.0    434.49    Methadone
#
#         TotalCount  NonUSBorn    EducationType  EducationCount  \
# ...

# %%
incomedf = cleaneddf.sort_values(["Income"], ascending=True)
incomedf
# Out:
#                  State   County  Year  Population  LandArea         Type  \
# 327370  North Carolina  Robeson  2013    134841.0    949.22    Methadone
# 189445  North Carolina  Robeson  2013    134841.0    949.22  Other Opiod
# 189444  North Carolina  Robeson  2013    134841.0    949.22  Other Opiod
# 189443  North Carolina  Robeson  2013    134841.0    949.22  Other Opiod
# 189442  North Carolina  Robeson  2013    134841.0    949.22  Other Opiod
# ...                ...      ...   ...         ...       ...          ...
# 257005      California    Marin  2017    260955.0    520.31  Other Opiod
# 257004      California    Marin  2017    260955.0    520.31  Other Opiod
# 257003      California    Marin  2017    260955.0    520.31  Other Opiod
# 257015      California    Marin  2017    260955.0    520.31  Other Opiod
# 119124      California    Marin  2017    260955.0    520.31       Heroin
#
#         TotalCount  NonUSBorn                   EducationType  EducationCount  \
# ...

# %%
cleaneddf.to_csv('CleanedUpData.csv')

# %%
grouped = cleaneddf.groupby(['Year','State','County']).first()

# %%
grouped
# Out:
#                            Population  LandArea    Type  TotalCount  \
# Year State     County
# 2011 Alabama   Baldwin       186717.0   1589.78  Heroin        10.0
#                Jefferson     658931.0   1111.28  Heroin        39.0
#                Madison       340111.0    801.59  Heroin        14.0
#                Mobile        412577.0   1229.44  Heroin        12.0
#                Shelby        197936.0    784.93  Heroin        10.0
# ...                               ...       ...     ...         ...
# 2017 Wisconsin Rock          162309.0    718.14  Heroin        29.0
#                Sheboygan     115344.0    511.27  Heroin        15.0
#                Washington    135101.0    430.70  Heroin        18.0
#                Waukesha      400621.0    549.57  Heroin        52.0
#                Winnebago     170414.0    434.49  Heroin        16.0
#
#                            NonUSBorn EducationType  EducationCount  \
# Year State     County
# ...

# %%
educated = cleaneddf.loc[cleaneddf['EducationType'] == 'Bachelor Degree']
educated2 = cleaneddf.loc[cleaneddf['EducationType'] == 'Grad Degree']

# %%
columns = ['Population', 'LandArea', 'Type', 'TotalCount', 'NonUSBorn', 'CommuteType', 'Income']
educated.drop(columns, inplace=True, axis=1)
# Out:
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_2994/2802295185.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educated.drop(columns, inplace=True, axis=1)

# %%
columns = ['Population', 'LandArea', 'Type', 'TotalCount', 'NonUSBorn', 'CommuteType', 'Income']
educated2.drop(columns, inplace=True, axis=1)
# Out:
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_2994/26481877.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   educated2.drop(columns, inplace=True, axis=1)

# %%
educatedcomplete = pd.concat([educated, educated2], axis=0)

# %%
educatedcomplete.to_csv('EducatedComplete.csv')

# %%
educatedcomplete
# Out:
#             State     County  Year    EducationType  EducationCount
# 18        Alabama    Baldwin  2011  Bachelor Degree         22946.0
# 19        Alabama    Baldwin  2011  Bachelor Degree         22946.0
# 20        Alabama    Baldwin  2011  Bachelor Degree         22946.0
# 21        Alabama    Baldwin  2011  Bachelor Degree         22946.0
# 22        Alabama    Baldwin  2011  Bachelor Degree         22946.0
# ...           ...        ...   ...              ...             ...
# 413663  Wisconsin  Winnebago  2017      Grad Degree          8838.0
# 413664  Wisconsin  Winnebago  2017      Grad Degree          8838.0
# 413665  Wisconsin  Winnebago  2017      Grad Degree          8838.0
# 413666  Wisconsin  Winnebago  2017      Grad Degree          8838.0
# 413667  Wisconsin  Winnebago  2017      Grad Degree          8838.0
#
# [114552 rows x 5 columns]

# %%
uneducated = cleaneddf.loc[cleaneddf['EducationType'] == 'Less Than HS']
uneducated2 = cleaneddf.loc[cleaneddf['EducationType'] == 'HS Grad']
uneducated3 = cleaneddf.loc[cleaneddf['EducationType'] == 'Some College/Associates Degree']

# %%
columns = ['Population', 'LandArea', 'Type', 'TotalCount', 'NonUSBorn', 'CommuteType', 'Income']
uneducated.drop(columns, inplace=True, axis=1)
# Out:
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_2994/3258897380.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uneducated.drop(columns, inplace=True, axis=1)

# %%
columns = ['Population', 'LandArea', 'Type', 'TotalCount', 'NonUSBorn', 'CommuteType', 'Income']
uneducated2.drop(columns, inplace=True, axis=1)
# Out:
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_2994/4140876450.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uneducated2.drop(columns, inplace=True, axis=1)

# %%
columns = ['Population', 'LandArea', 'Type', 'TotalCount', 'NonUSBorn', 'CommuteType', 'Income']
uneducated3.drop(columns, inplace=True, axis=1)
# Out:
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_2994/1026771162.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uneducated3.drop(columns, inplace=True, axis=1)

# %%
uneducatedcomplete = pd.concat([uneducated, uneducated2], axis=0)

# %%
uneducatedcomplete2 = pd.concat([uneducatedcomplete, uneducated3], axis=0)

# %%
uneducatedcomplete2.to_csv('UneducatedComplete.csv')

# %%
uneducatedcomplete2
# Out:
#             State     County  Year                   EducationType  \
# 0         Alabama    Baldwin  2011                    Less Than HS
# 1         Alabama    Baldwin  2011                    Less Than HS
# 2         Alabama    Baldwin  2011                    Less Than HS
# 3         Alabama    Baldwin  2011                    Less Than HS
# 4         Alabama    Baldwin  2011                    Less Than HS
# ...           ...        ...   ...                             ...
# 413651  Wisconsin  Winnebago  2017  Some College/Associates Degree
# 413652  Wisconsin  Winnebago  2017  Some College/Associates Degree
# 413653  Wisconsin  Winnebago  2017  Some College/Associates Degree
# 413654  Wisconsin  Winnebago  2017  Some College/Associates Degree
# 413655  Wisconsin  Winnebago  2017  Some College/Associates Degree
#
#         EducationCount
# 0              15094.0
# 1              15094.0
# 2              15094.0
# 3              15094.0
# 4              15094.0
# ...

# %%
populationdf = cleaneddf.sort_values(["Population"], ascending=True)

# %%
columns = ['LandArea', 'Type', 'TotalCount', 'NonUSBorn', 'EducationType', 'EducationCount', 'CommuteType', 'Income']
populationdf.drop(columns, inplace=True, axis=1)

# %%
populationdf
# Out:
#              State       County  Year  Population
# 85109     Kentucky         Pike  2015     61792.0
# 360915    Kentucky         Pike  2015     61792.0
# 360914    Kentucky         Pike  2015     61792.0
# 360913    Kentucky         Pike  2015     61792.0
# 360912    Kentucky         Pike  2015     61792.0
# ...            ...          ...   ...         ...
# 217516  California  Los Angeles  2015  10170292.0
# 217515  California  Los Angeles  2015  10170292.0
# 217514  California  Los Angeles  2015  10170292.0
# 217512  California  Los Angeles  2015  10170292.0
# 217506  California  Los Angeles  2015  10170292.0
#
# [286380 rows x 4 columns]

# %%
populationdf.to_csv('PopulationComplete.csv')
