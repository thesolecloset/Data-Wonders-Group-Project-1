# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
datadf = pd.read_csv("master2.csv")
datadf.info()
# Out:
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_41730/2323851212.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   datadf = pd.read_csv("master2.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528644 entries, 0 to 528643
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      528644 non-null  int64
#  1   State           528644 non-null  object
#  2   County          528644 non-null  object
#  3   Year            528644 non-null  int64
#  4   Population      526949 non-null  float64
#  5   LandArea        526949 non-null  float64
#  6   Type            413703 non-null  object
#  7   CountByType     128859 non-null  float64
#  8   TotalCount      291792 non-null  float64
#  9   NonUSBorn       528490 non-null  float64
#  10  EducationType   528490 non-null  object
#  11  EducationCount  528490 non-null  float64
#  12  CommuteType     437592 non-null  object
#  13  CommuteCount    386712 non-null  float64
#  14  Income          528490 non-null  float64
# dtypes: float64(8), int64(2), object(5)
# memory usage: 60.5+ MB

# %%
datadf.head(50)
# Out:
#       State   County  Year  Population  LandArea    Type  CountByType  \
# 0   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 1   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 2   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 3   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 4   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 5   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 6   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 7   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 8   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 9   Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 10  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 11  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 12  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 13  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 14  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 15  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 16  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 17  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 18  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 19  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 20  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 21  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 22  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 23  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 24  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 25  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 26  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 27  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 28  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 29  Alabama  Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 30  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 31  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 32  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 33  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 34  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 35  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 36  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 37  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 38  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 39  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 40  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 41  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 42  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 43  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 44  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 45  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 46  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 47  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 48  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
# 49  Alabama  Cullman  2011     80536.0    734.84  Heroin          NaN
#
#     TotalCount  NonUSBorn                   EducationType  EducationCount  \
# 0         10.0     5147.0                    Less Than HS         15094.0
# 1         10.0     5147.0                    Less Than HS         15094.0
# 2         10.0     5147.0                    Less Than HS         15094.0
# 3         10.0     5147.0                    Less Than HS         15094.0
# 4         10.0     5147.0                    Less Than HS         15094.0
# 5         10.0     5147.0                    Less Than HS         15094.0
# 6         10.0     5147.0                         HS Grad         36271.0
# 7         10.0     5147.0                         HS Grad         36271.0
# 8         10.0     5147.0                         HS Grad         36271.0
# 9         10.0     5147.0                         HS Grad         36271.0
# 10        10.0     5147.0                         HS Grad         36271.0
# 11        10.0     5147.0                         HS Grad         36271.0
# 12        10.0     5147.0  Some College/Associates Degree         39216.0
# 13        10.0     5147.0  Some College/Associates Degree         39216.0
# 14        10.0     5147.0  Some College/Associates Degree         39216.0
# 15        10.0     5147.0  Some College/Associates Degree         39216.0
# 16        10.0     5147.0  Some College/Associates Degree         39216.0
# 17        10.0     5147.0  Some College/Associates Degree         39216.0
# 18        10.0     5147.0                 Bachelor Degree         22946.0
# 19        10.0     5147.0                 Bachelor Degree         22946.0
# 20        10.0     5147.0                 Bachelor Degree         22946.0
# 21        10.0     5147.0                 Bachelor Degree         22946.0
# 22        10.0     5147.0                 Bachelor Degree         22946.0
# 23        10.0     5147.0                 Bachelor Degree         22946.0
# 24        10.0     5147.0                     Grad Degree         10923.0
# 25        10.0     5147.0                     Grad Degree         10923.0
# 26        10.0     5147.0                     Grad Degree         10923.0
# 27        10.0     5147.0                     Grad Degree         10923.0
# 28        10.0     5147.0                     Grad Degree         10923.0
# 29        10.0     5147.0                     Grad Degree         10923.0
# 30         9.0     1582.0                    Less Than HS         12788.0
# 31         9.0     1582.0                    Less Than HS         12788.0
# 32         9.0     1582.0                    Less Than HS         12788.0
# 33         9.0     1582.0                    Less Than HS         12788.0
# 34         9.0     1582.0                    Less Than HS         12788.0
# 35         9.0     1582.0                    Less Than HS         12788.0
# 36         9.0     1582.0                         HS Grad         17883.0
# 37         9.0     1582.0                         HS Grad         17883.0
# 38         9.0     1582.0                         HS Grad         17883.0
# 39         9.0     1582.0                         HS Grad         17883.0
# 40         9.0     1582.0                         HS Grad         17883.0
# 41         9.0     1582.0                         HS Grad         17883.0
# 42         9.0     1582.0  Some College/Associates Degree         16286.0
# 43         9.0     1582.0  Some College/Associates Degree         16286.0
# 44         9.0     1582.0  Some College/Associates Degree         16286.0
# 45         9.0     1582.0  Some College/Associates Degree         16286.0
# 46         9.0     1582.0  Some College/Associates Degree         16286.0
# 47         9.0     1582.0  Some College/Associates Degree         16286.0
# 48         9.0     1582.0                 Bachelor Degree          4807.0
# 49         9.0     1582.0                 Bachelor Degree          4807.0
#
#        CommuteType   Income
# 0            Alone  67770.0
# 1          Carpool  67770.0
# 2             Walk  67770.0
# 3   Public Transit  67770.0
# 4             Bike  67770.0
# 5   Work From Home  67770.0
# 6            Alone  67770.0
# 7          Carpool  67770.0
# 8             Walk  67770.0
# 9   Public Transit  67770.0
# 10            Bike  67770.0
# 11  Work From Home  67770.0
# 12           Alone  67770.0
# 13         Carpool  67770.0
# 14            Walk  67770.0
# 15  Public Transit  67770.0
# 16            Bike  67770.0
# 17  Work From Home  67770.0
# 18           Alone  67770.0
# 19         Carpool  67770.0
# 20            Walk  67770.0
# 21  Public Transit  67770.0
# 22            Bike  67770.0
# 23  Work From Home  67770.0
# 24           Alone  67770.0
# 25         Carpool  67770.0
# 26            Walk  67770.0
# 27  Public Transit  67770.0
# 28            Bike  67770.0
# 29  Work From Home  67770.0
# 30           Alone  51374.0
# 31         Carpool  51374.0
# 32            Walk  51374.0
# 33  Public Transit  51374.0
# 34            Bike  51374.0
# 35  Work From Home  51374.0
# 36           Alone  51374.0
# 37         Carpool  51374.0
# 38            Walk  51374.0
# 39  Public Transit  51374.0
# 40            Bike  51374.0
# 41  Work From Home  51374.0
# 42           Alone  51374.0
# 43         Carpool  51374.0
# 44            Walk  51374.0
# 45  Public Transit  51374.0
# 46            Bike  51374.0
# 47  Work From Home  51374.0
# 48           Alone  51374.0
# 49         Carpool  51374.0

# %%
datadf["Type"].value_counts()
# Out:
# Heroin         137901
# Other Opiod    137901
# Methadone      137901
# Name: Type, dtype: int64

# %%
datadf["County"].value_counts()
# Out:
# Washington         6125
# Jefferson          5880
# Madison            4060
# Montgomery         3955
# Monroe             3570
#                    ...
# Prince of Wales       7
# Do¸æç£§ºa Ana         7
# Yukon                 7
# Matanuska             7
# La Salle Parish       5
# Name: County, Length: 1890, dtype: int64

# %%
datadf["EducationType"].value_counts()
# Out:
# Less Than HS                      105698
# HS Grad                           105698
# Some College/Associates Degree    105698
# Bachelor Degree                   105698
# Grad Degree                       105698
# Name: EducationType, dtype: int64

# %%
datadf["State"].value_counts()
# Out:
# Texas             28270
# North Carolina    27300
# Florida           25362
# Ohio              25075
# Pennsylvania      24255
# California        23100
# New York          23065
# Georgia           22155
# Virginia          19230
# Michigan          18200
# Illinois          16555
# Indiana           15930
# Tennessee         15645
# Wisconsin         14665
# New Jersey        12390
# Kentucky          12355
# South Carolina    12100
# Washington        11970
# Missouri          11270
# Maryland          10590
# Alabama           10220
# Oklahoma           9310
# Minnesota          9200
# Colorado           8860
# Louisiana          8645
# Oregon             8155
# Iowa               7735
# Massachusetts      7630
# Kansas             7595
# West Virginia      7420
# Mississippi        6790
# Arkansas           6720
# New Mexico         5950
# Connecticut        5040
# Utah               4940
# Arizona            4795
# Nebraska           4620
# Idaho              4270
# Maine              4270
# New Hampshire      3570
# Montana            3380
# South Dakota       3080
# North Dakota       2925
# Rhode Island       2625
# Alaska             2527
# Hawaii             2135
# Nevada             1995
# Delaware           1890
# Wyoming            1645
# Vermont            1225
# Name: State, dtype: int64

# %%
columns = ['Unnamed: 0', 'CommuteCount']
datadf.drop(columns, inplace=True, axis=1)

# %%
datadf
# Out:
#              State    County  Year  Population  LandArea    Type  CountByType  \
# 0          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 1          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 2          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 3          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 4          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# ...            ...       ...   ...         ...       ...     ...          ...
# 528639  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
# 528640  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
# 528641  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
# 528642  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
# 528643  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
#
#         TotalCount  NonUSBorn EducationType  EducationCount     CommuteType  \
# 0             10.0     5147.0  Less Than HS         15094.0           Alone
# 1             10.0     5147.0  Less Than HS         15094.0         Carpool
# 2             10.0     5147.0  Less Than HS         15094.0            Walk
# 3             10.0     5147.0  Less Than HS         15094.0  Public Transit
# 4             10.0     5147.0  Less Than HS         15094.0            Bike
# ...            ...        ...           ...             ...             ...
# 528639         9.0        NaN           NaN             NaN         Carpool
# 528640         9.0        NaN           NaN             NaN            Walk
# 528641         9.0        NaN           NaN             NaN  Public Transit
# 528642         9.0        NaN           NaN             NaN            Bike
# 528643         9.0        NaN           NaN             NaN  Work From Home
#
#          Income
# 0       67770.0
# 1       67770.0
# 2       67770.0
# 3       67770.0
# 4       67770.0
# ...         ...
# 528639      0.0
# 528640      0.0
# 528641      0.0
# 528642      0.0
# 528643      0.0
#
# [528644 rows x 13 columns]

# %%
datadf.TotalCount.fillna(9, inplace=True)
datadf.Income.fillna(0, inplace=True)
datadf
# Out:
#              State    County  Year  Population  LandArea    Type  CountByType  \
# 0          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 1          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 2          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 3          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# 4          Alabama   Baldwin  2011    186717.0   1589.78  Heroin          NaN
# ...            ...       ...   ...         ...       ...     ...          ...
# 528639  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
# 528640  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
# 528641  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
# 528642  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
# 528643  New Mexico  Do?a Ana  2017         NaN       NaN     NaN          NaN
#
#         TotalCount  NonUSBorn EducationType  EducationCount     CommuteType  \
# 0             10.0     5147.0  Less Than HS         15094.0           Alone
# 1             10.0     5147.0  Less Than HS         15094.0         Carpool
# 2             10.0     5147.0  Less Than HS         15094.0            Walk
# 3             10.0     5147.0  Less Than HS         15094.0  Public Transit
# 4             10.0     5147.0  Less Than HS         15094.0            Bike
# ...            ...        ...           ...             ...             ...
# 528639         9.0        NaN           NaN             NaN         Carpool
# 528640         9.0        NaN           NaN             NaN            Walk
# 528641         9.0        NaN           NaN             NaN  Public Transit
# 528642         9.0        NaN           NaN             NaN            Bike
# 528643         9.0        NaN           NaN             NaN  Work From Home
#
#          Income
# 0       67770.0
# 1       67770.0
# 2       67770.0
# 3       67770.0
# 4       67770.0
# ...         ...
# 528639      0.0
# 528640      0.0
# 528641      0.0
# 528642      0.0
# 528643      0.0
#
# [528644 rows x 13 columns]

# %%
cleaneddatadf = datadf.groupby(["State","County","Year"]).first()
cleaneddatadf.head(100)
# Out:
#                        Population  LandArea  Type  CountByType  TotalCount  \
# State   County   Year
# Alabama Autauga  2011     55267.0    594.44  None          NaN         9.0
#                  2012     55514.0    594.44  None          NaN         9.0
#                  2013     55246.0    594.44  None          NaN         9.0
#                  2014     55395.0    594.44  None          NaN         9.0
#                  2015     55347.0    594.44  None          NaN         9.0
# ...                           ...       ...   ...          ...         ...
#         Clay     2015     13555.0    603.96  None          NaN         9.0
#                  2016     13492.0    603.96  None          NaN         9.0
#                  2017     13367.0    603.96  None          NaN         9.0
#         Cleburne 2011     14835.0    560.10  None          NaN         9.0
#                  2012     14832.0    560.10  None          NaN         9.0
#
#                        NonUSBorn EducationType  EducationCount CommuteType  \
# State   County   Year
# Alabama Autauga  2011      759.0  Less Than HS          4685.0        None
#                  2012      591.0  Less Than HS          5232.0        None
#                  2013      661.0  Less Than HS          5143.0        None
#                  2014      626.0  Less Than HS          5012.0        None
#                  2015      670.0  Less Than HS          4656.0        None
# ...                          ...           ...             ...         ...
#         Clay     2015      260.0  Less Than HS          2377.0        None
#                  2016      246.0  Less Than HS          2398.0        None
#                  2017      261.0  Less Than HS          2525.0        None
#         Cleburne 2011      103.0  Less Than HS          2745.0        None
#                  2012      110.0  Less Than HS          2622.0        None
#
#                         Income
# State   County   Year
# Alabama Autauga  2011  66457.0
#                  2012  66679.0
#                  2013  64699.0
#                  2014  64414.0
#                  2015  64765.0
# ...                        ...
#         Clay     2015  44846.0
#                  2016  50719.0
#                  2017  51364.0
#         Cleburne 2011  49767.0
#                  2012  49832.0
#
# [100 rows x 10 columns]

# %%
casualtysumdf = cleaneddatadf.groupby(by=("Year"))["TotalCount"].sum()

casualtysumdf
# Out:
# Year
# 2011    39739.0
# 2012    40057.0
# 2013    41670.0
# 2014    43906.0
# 2015    46135.0
# 2016    49670.0
# 2017    49608.0
# Name: TotalCount, dtype: float64

# %%
cleaneddatadf
# Out:
#                       Population  LandArea  Type  CountByType  TotalCount  \
# State   County  Year
# Alabama Autauga 2011     55267.0    594.44  None          NaN         9.0
#                 2012     55514.0    594.44  None          NaN         9.0
#                 2013     55246.0    594.44  None          NaN         9.0
#                 2014     55395.0    594.44  None          NaN         9.0
#                 2015     55347.0    594.44  None          NaN         9.0
# ...                          ...       ...   ...          ...         ...
# Wyoming Weston  2013      7158.0   2398.09  None          NaN         9.0
#                 2014      7201.0   2398.09  None          NaN         9.0
#                 2015      7234.0   2398.09  None          NaN         9.0
#                 2016      7236.0   2398.09  None          NaN         9.0
#                 2017      6927.0   2398.09  None          NaN         9.0
#
#                       NonUSBorn EducationType  EducationCount CommuteType  \
# State   County  Year
# Alabama Autauga 2011      759.0  Less Than HS          4685.0        None
#                 2012      591.0  Less Than HS          5232.0        None
#                 2013      661.0  Less Than HS          5143.0        None
#                 2014      626.0  Less Than HS          5012.0        None
#                 2015      670.0  Less Than HS          4656.0        None
# ...                         ...           ...             ...         ...
# Wyoming Weston  2013       19.0  Less Than HS           493.0        None
#                 2014       90.0  Less Than HS           573.0        None
#                 2015       46.0  Less Than HS           610.0        None
#                 2016      246.0  Less Than HS           445.0        None
#                 2017      234.0  Less Than HS           410.0        None
#
#                        Income
# State   County  Year
# Alabama Autauga 2011  66457.0
#                 2012  66679.0
#                 2013  64699.0
#                 2014  64414.0
#                 2015  64765.0
# ...                       ...
# Wyoming Weston  2013  65573.0
#                 2014  66972.0
#                 2015  69975.0
#                 2016  67135.0
#                 2017  70589.0
#
# [22067 rows x 10 columns]

# %%
totalcountsum = cleaneddatadf.groupby(by=("Year"))["TotalCount"].sum()
totalcountsum_df = pd.DataFrame(totalcountsum)
totalcountsum_df
# Out:
#       TotalCount
# Year
# 2011     39739.0
# 2012     40057.0
# 2013     41670.0
# 2014     43906.0
# 2015     46135.0
# 2016     49670.0
# 2017     49608.0

# %%
Y_axis = totalcountsum_df["TotalCount"]
totalcountsum_df.plot(kind="bar")
plt.title("Deaths from Opiod Consumption in US (2011-2017)")
plt.ylabel("Opiod Deaths")
plt.show()

# %%
cleaneddatamean = datadf.groupby(["Year"]).mean()["Income"]
cleaneddatamean_df = pd.DataFrame(cleaneddatamean)
cleaneddatamean_df
# Out:
#             Income
# Year
# 2011  67388.720451
# 2012  67855.034690
# 2013  68289.154353
# 2014  69296.383197
# 2015  70039.953674
# 2016  72110.294977
# 2017  75087.961174

# %%
plt.scatter(cleaneddatamean_df["Income"], totalcountsum_df['TotalCount'], marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title(f'Income vs. Opiod Deaths (2011-2017)')
plt.ylabel("Opiod Deaths")
plt.xlabel("Average Income")
plt.ylim(30000, max(totalcountsum_df['TotalCount'])+10000)
plt.grid(True)


x_axis = cleaneddatamean_df["Income"]
y_axis = totalcountsum_df['TotalCount']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
# y = mx + b
regress_values = x_axis * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values, color='r', alpha=0.5)
print(line_equation)

# Calculate r-squared
r_squared = round(rvalue**2,2)
print(f"The r-squared is: {r_squared}")


# Add line Annotation and r-squared to the graph 
plt.annotate(line_equation,(68000,51000), fontsize=11, color="red")
plt.annotate(f'r-squared = {r_squared}', (68000,50000), fontsize=11, color="red")
plt.show()
plt.close()
# Out:
# y = 1.42x + -55067.58
# The r-squared is: 0.86

# %%
cleaneddatadf2 = datadf.groupby(["Year","Type","EducationType"]).first()
cleaneddatadf2
# Out:
#                                                    State   County  Population  \
# Year Type        EducationType
# 2011 Heroin      Bachelor Degree                 Alabama  Baldwin    186717.0
#                  Grad Degree                     Alabama  Baldwin    186717.0
#                  HS Grad                         Alabama  Baldwin    186717.0
#                  Less Than HS                    Alabama  Baldwin    186717.0
#                  Some College/Associates Degree  Alabama  Baldwin    186717.0
# ...                                                  ...      ...         ...
# 2017 Other Opiod Bachelor Degree                 Alabama  Baldwin    212628.0
#                  Grad Degree                     Alabama  Baldwin    212628.0
#                  HS Grad                         Alabama  Baldwin    212628.0
#                  Less Than HS                    Alabama  Baldwin    212628.0
#                  Some College/Associates Degree  Alabama  Baldwin    212628.0
#
#                                                  LandArea  CountByType  \
# Year Type        EducationType
# 2011 Heroin      Bachelor Degree                  1589.78         10.0
#                  Grad Degree                      1589.78         10.0
#                  HS Grad                          1589.78         10.0
#                  Less Than HS                     1589.78         10.0
#                  Some College/Associates Degree   1589.78         10.0
# ...                                                   ...          ...
# 2017 Other Opiod Bachelor Degree                  1589.78         11.0
#                  Grad Degree                      1589.78         11.0
#                  HS Grad                          1589.78         11.0
#                  Less Than HS                     1589.78         11.0
#                  Some College/Associates Degree   1589.78         11.0
#
#                                                  TotalCount  NonUSBorn  \
# Year Type        EducationType
# 2011 Heroin      Bachelor Degree                       10.0     5147.0
#                  Grad Degree                           10.0     5147.0
#                  HS Grad                               10.0     5147.0
#                  Less Than HS                          10.0     5147.0
#                  Some College/Associates Degree        10.0     5147.0
# ...                                                     ...        ...
# 2017 Other Opiod Bachelor Degree                       15.0     5703.0
#                  Grad Degree                           15.0     5703.0
#                  HS Grad                               15.0     5703.0
#                  Less Than HS                          15.0     5703.0
#                  Some College/Associates Degree        15.0     5703.0
#
#                                                  EducationCount CommuteType  \
# Year Type        EducationType
# 2011 Heroin      Bachelor Degree                        22946.0       Alone
#                  Grad Degree                            10923.0       Alone
#                  HS Grad                                36271.0       Alone
#                  Less Than HS                           15094.0       Alone
#                  Some College/Associates Degree         39216.0       Alone
# ...                                                         ...         ...
# 2017 Other Opiod Bachelor Degree                        29237.0       Alone
#                  Grad Degree                            14731.0       Alone
#                  HS Grad                                39771.0       Alone
#                  Less Than HS                           13997.0       Alone
#                  Some College/Associates Degree         45286.0       Alone
#
#                                                   Income
# Year Type        EducationType
# 2011 Heroin      Bachelor Degree                 67770.0
#                  Grad Degree                     67770.0
#                  HS Grad                         67770.0
#                  Less Than HS                    67770.0
#                  Some College/Associates Degree  67770.0
# ...                                                  ...
# 2017 Other Opiod Bachelor Degree                 73061.0
#                  Grad Degree                     73061.0
#                  HS Grad                         73061.0
#                  Less Than HS                    73061.0
#                  Some College/Associates Degree  73061.0
#
# [105 rows x 10 columns]

# %%
cleaneddatadf3 = cleaneddatadf2.groupby(['Type'] == ['Heroine']).count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/q_/r75nrh6s617gpc42hwkzqy6c0000gn/T/ipykernel_41730/3874516403.py in <module>
# ----> 1 cleaneddatadf3 = cleaneddatadf2.groupby(['Type'] == ['Heroine']).count
#
# NameError: name 'cleaneddatadf2' is not defined

# %%
datadf.groupby(["Year","Type","EducationType"])
